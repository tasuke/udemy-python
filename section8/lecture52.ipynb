# %%
import numpy as np
from numpy.random import randn
import pandas as pd

from scipy import stats

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.lmplot('total_bill', 'tip', tips)

# %%
sns.lmplot('total_bill', 'tip', tips,
          scatter_kws={'marker':'o', 'color':'indianred'},
          line_kws={'linewidth':1, 'color':'blue'})

# %%
sns.lmplot('total_bill', 'tip', tips, order=4,
          scatter_kws={'marker':'o', 'color':'indianred'},
          line_kws={'linewidth':1, 'color':'blue'})

# %%
sns.lmplot('total_bill', 'tip', tips, fit_reg=False)

# %%
tips['tips_pect'] = 100 * (tips['tip']/tips['total_bill'])

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  tips_pect
# 0       16.99  1.01  Female     No  Sun  Dinner     2   5.944673
# 1       10.34  1.66    Male     No  Sun  Dinner     3  16.054159
# 2       21.01  3.50    Male     No  Sun  Dinner     3  16.658734
# 3       23.68  3.31    Male     No  Sun  Dinner     2  13.978041
# 4       24.59  3.61  Female     No  Sun  Dinner     4  14.680765

# %%
sns.lmplot('size', 'tips_pect', tips)

# %%
sns.lmplot('size', 'tips_pect', tips, x_jitter=0.3)

# %%
sns.lmplot('size', 'tips_pect', tips, x_estimator=np.mean, order=4)

# %%
sns.lmplot('total_bill', 'tips_pect', tips, hue='sex', markers=["x","o"])

# %%
sns.lmplot('total_bill', 'tips_pect', tips, hue='day')

# %%
sns.lmplot('total_bill', 'tips_pect', tips, lowess=True, line_kws={'color':'black'})

# %%
sns.regplot('total_bill', 'tips_pect', tips)

# %%
# 描画のエリアを分割することもできます。
fig, (axis1,axis2) = plt.subplots(1,2,sharey =True)

sns.regplot("total_bill","tips_pect",tips,ax=axis1)
sns.violinplot(y='tip_pect', x='size', data=tips.sort_values('size') ,ax=axis2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-71518726547e> in <module>
#       3
#       4 sns.regplot("total_bill","tips_pect",tips,ax=axis1)
# ----> 5 sns.violinplot(y='tip_pect', x='size', data=tips.sort_values('size') ,ax=axis2)
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in violinplot(x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2385                              bw, cut, scale, scale_hue, gridsize,
#    2386                              width, inner, split, dodge, orient, linewidth,
# -> 2387                              color, palette, saturation)
#    2388
#    2389     if ax is None:
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation)
#     560                  color, palette, saturation):
#     561
# --> 562         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#     563         self.establish_colors(color, palette, saturation)
#     564         self.estimate_densities(bw, cut, scale, scale_hue, gridsize)
#
# /opt/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'tip_pect'
