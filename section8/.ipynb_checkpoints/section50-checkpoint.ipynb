# %%
from numpy.random import randn
import seaborn as sns

# %matplotlib inline

# %%
dataset = randn(100)

# %%
sns.distplot(dataset)

# %%
sns.distplot(dataset, rug=True, hist=False)

# %%
sns.distplot(dataset, bins=25,
            kde_kws={'color':'indianred', 'label':'KDE_PLOT'},
            hist_kws={'color':'blue', 'label':'HIST_PLOT'})

# %%
from pandas import Series

# %%
ser1 = Series(dataset, name='My_Data')

# %%
ser1
# Out:
# 0     0.910190
# 1     0.485542
# 2    -1.015564
# 3     0.116804
# 4     0.962331
#         ...
# 95    0.177539
# 96    1.329489
# 97    0.701395
# 98   -0.274366
# 99   -0.538068
# Name: My_Data, Length: 100, dtype: float64

# %%
sns.distplot(ser1)
